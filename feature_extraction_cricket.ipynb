# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzer/Bioactivity-Prediction-App/blob/main/feature_extraction_cricket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city                            venue
# 0       Colombo  R.Premadasa Stadium, Khettarama
# 1       Colombo  R.Premadasa Stadium, Khettarama
# 2       Colombo  R.Premadasa Stadium, Khettarama
# 3       Colombo  R.Premadasa Stadium, Khettarama
# 4       Colombo  R.Premadasa Stadium, Khettarama
# ..          ...                              ...
# 122  Wellington                  Westpac Stadium
# 123  Wellington                  Westpac Stadium
# 124  Wellington                  Westpac Stadium
# 125  Wellington                  Westpac Stadium
# 126  Wellington                  Westpac Stadium
#
# [64141 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8549
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2970
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city
# 0       Colombo
# 1       Colombo
# 2       Colombo
# 3       Colombo
# 4       Colombo
# ..          ...
# 122  Wellington
# 123  Wellington
# 124  Wellington
# 125  Wellington
# 126  Wellington
#
# [64141 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city
# 0       Colombo
# 1       Colombo
# 2       Colombo
# 3       Colombo
# 4       Colombo
# ..          ...
# 122  Wellington
# 123  Wellington
# 124  Wellington
# 125  Wellington
# 126  Wellington
#
# [50509 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city  current_score
# 0       Colombo              0
# 1       Colombo              0
# 2       Colombo              0
# 3       Colombo              1
# 4       Colombo              2
# ..          ...            ...
# 122  Wellington            160
# 123  Wellington            161
# 124  Wellington            163
# 125  Wellington            164
# 126  Wellington            165
#
# [50509 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city  current_score over ball_no
# 0       Colombo              0    0       1
# 1       Colombo              0    0       2
# 2       Colombo              0    0       3
# 3       Colombo              1    0       4
# 4       Colombo              2    0       5
# ..          ...            ...  ...     ...
# 122  Wellington            160   19       3
# 123  Wellington            161   19       4
# 124  Wellington            163   19       5
# 125  Wellington            164   19       6
# 126  Wellington            165   19       7
#
# [50509 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city  current_score over ball_no  balls_bowled
# 0       Colombo              0    0       1             1
# 1       Colombo              0    0       2             2
# 2       Colombo              0    0       3             3
# 3       Colombo              1    0       4             4
# 4       Colombo              2    0       5             5
# ..          ...            ...  ...     ...           ...
# 122  Wellington            160   19       3           117
# 123  Wellington            161   19       4           118
# 124  Wellington            163   19       5           119
# 125  Wellington            164   19       6           120
# 126  Wellington            165   19       7           121
#
# [50509 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city  current_score over ball_no  balls_bowled  balls_left
# 0       Colombo              0    0       1             1         119
# 1       Colombo              0    0       2             2         118
# 2       Colombo              0    0       3             3         117
# 3       Colombo              1    0       4             4         116
# 4       Colombo              2    0       5             5         115
# ..          ...            ...  ...     ...           ...         ...
# 122  Wellington            160   19       3           117           3
# 123  Wellington            161   19       4           118           2
# 124  Wellington            163   19       5           119           1
# 125  Wellington            164   19       6           120           0
# 126  Wellington            165   19       7           121           0
#
# [50509 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                 0
# 1           4    Sri Lanka   Bangladesh   0.2     0                 0
# 2           4    Sri Lanka   Bangladesh   0.3     0                 0
# 3           4    Sri Lanka   Bangladesh   0.4     1                 0
# 4           4    Sri Lanka   Bangladesh   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 122       964        India  New Zealand  19.3     1                 8
# 123       964        India  New Zealand  19.4     1                 8
# 124       964        India  New Zealand  19.5     2                 8
# 125       964        India  New Zealand  19.6     1                 8
# 126       964        India  New Zealand  19.7     1                 8
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Colombo              0    0       1             1         119
# 1       Colombo              0    0       2             2         118
# 2       Colombo              0    0       3             3         117
# 3       Colombo              1    0       4             4         116
# 4       Colombo              2    0       5             5         115
# ..          ...            ...  ...     ...           ...         ...
# 122  Wellington            160   19       3           117           3
# 123  Wellington            161   19       4           118           2
# 124  Wellington            163   19       5           119           1
# 125  Wellington            164   19       6           120           0
# 126  Wellington            165   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 122             2
# 123             2
# 124             2
# 125             2
# 126             2
#
# [50509 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                 0
# 1           4    Sri Lanka   Bangladesh   0.2     0                 0
# 2           4    Sri Lanka   Bangladesh   0.3     0                 0
# 3           4    Sri Lanka   Bangladesh   0.4     1                 0
# 4           4    Sri Lanka   Bangladesh   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 122       964        India  New Zealand  19.3     1                 8
# 123       964        India  New Zealand  19.4     1                 8
# 124       964        India  New Zealand  19.5     2                 8
# 125       964        India  New Zealand  19.6     1                 8
# 126       964        India  New Zealand  19.7     1                 8
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Colombo              0    0       1             1         119
# 1       Colombo              0    0       2             2         118
# 2       Colombo              0    0       3             3         117
# 3       Colombo              1    0       4             4         116
# 4       Colombo              2    0       5             5         115
# ..          ...            ...  ...     ...           ...         ...
# 122  Wellington            160   19       3           117           3
# 123  Wellington            161   19       4           118           2
# 124  Wellington            163   19       5           119           1
# 125  Wellington            164   19       6           120           0
# 126  Wellington            165   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  0.000000
# 3              10  1.500000
# 4              10  2.400000
# ..            ...       ...
# 122             2  8.205128
# 123             2  8.186441
# 124             2  8.218487
# 125             2  8.200000
# 126             2  8.181818
#
# [50509 rows x 14 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','']]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 20567  South Africa        India  Nottingham             61          64
# 12735  South Africa  Afghanistan      Mumbai            154          21
#
#        wickets_left       crr  last_five  runs_x
# 20567             8  6.535714       19.0     130
# 12735             7  9.333333       57.0     209

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 16939     Australia         India      Barbados            168          16
# 20228  South Africa       England        Mumbai            137          45
# 41258         India     Sri Lanka       Colombo             83          58
# 1058    West Indies      Pakistan      Barbados             63          32
# 8979        England  South Africa       Cardiff            127          39
# ...             ...           ...           ...            ...         ...
# 49529   West Indies  South Africa  Johannesburg             63          41
# 45434     Australia   West Indies      Barbados             72          74
# 26992  South Africa     Sri Lanka  Johannesburg             96          25
# 31886       England         India        London            121          17
# 21570      Pakistan     Australia      St Lucia             72          69
#
#        wickets_left        crr  last_five
# 16939             7   9.692308       42.0
# 20228             7  10.960000       39.0
# 41258             8   8.032258       46.0
# 1058              4   4.295455       20.0
# 8979              7   9.407407       55.0
# ...             ...        ...        ...
# 49529             6   4.784810       21.0
# 45434             9   9.391304       46.0
# 26992             3   6.063158       25.0
# 31886             7   7.048544       37.0
# 21570            10   8.470588       49.0
#
# [30788 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# [21:06:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9890449038206062
# 1.619429027413151

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '0.90'
