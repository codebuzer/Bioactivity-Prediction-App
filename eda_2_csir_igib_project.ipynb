# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzer/Bioactivity-Prediction-App/blob/main/eda_2_csir_igib_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("expmat.tsv", sep ='\t')

# %%
df2 = pd.read_csv("metadata.tsv", sep = '\t')

# %%
df2 = df2.iloc[:,1:]

# %%
df2
# Out:
#      infection batch  agenum  ctnum
# 0            1     I    64.0  18.88
# 1            1     I    30.0  21.18
# 2            1     I    47.0  24.24
# 3            1     G    67.0  18.91
# 4            1     H    62.0  25.62
# ..         ...   ...     ...    ...
# 479          0     S    41.0    NaN
# 480          0     S    22.0    NaN
# 481          0     U    59.0    NaN
# 482          0     U    49.0    NaN
# 483          0     R    75.0    NaN
#
# [484 rows x 4 columns]

# %%
df_concat = pd.concat([df1, df2], axis=1)

# %%
df_concat
# Out:
#         rowname        V1        V2        V3        V4        V5        V6  \
# 0    GSM4602241  0.290419  0.155136 -0.181369 -0.015744  0.039236 -0.146536
# 1    GSM4602242  0.033998 -0.073510 -0.024664 -0.020609 -0.070523 -0.111419
# 2    GSM4602243 -0.439669 -0.229209 -0.245936  0.268637  0.014308 -0.087299
# 3    GSM4602244 -0.151441 -0.187122 -0.383706 -0.242257 -0.217275 -0.420945
# 4    GSM4602245  0.330232  0.045676 -0.122178 -0.001248  0.065784 -0.180799
# ..          ...       ...       ...       ...       ...       ...       ...
# 479  GSM4602721  0.048350  0.203425  0.292148 -0.066557  0.333795  0.169132
# 480  GSM4602722  0.019730  0.113175  0.131340  0.304732  0.461142  0.259164
# 481  GSM4602723 -0.183947  0.139277  0.083529  0.105502  0.366155  0.324141
# 482  GSM4602724  0.195342 -0.092915 -0.058966 -0.243610 -0.122261 -0.072730
# 483  GSM4602725 -0.253828 -0.054208 -0.094667 -0.186982 -0.383879 -0.169531
#
# ...

# %%
y = df_concat['infection']

# %%
X = df_concat.drop(['infection'], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.25,random_state=42, shuffle = True)

# %%
y_test.value_counts()
# Out:
# 1    104
# 0     17
# Name: infection, dtype: int64

# %%
y_train.value_counts()
# Out:
# 1    326
# 0     37
# Name: infection, dtype: int64

# %%
X_train.describe()
# Out:
#                V1          V2          V3          V4          V5          V6  \
# count  363.000000  363.000000  363.000000  363.000000  363.000000  363.000000
# mean    -0.049593   -0.033994   -0.031281   -0.046495   -0.033435   -0.043426
# std      0.305039    0.152918    0.165474    0.206306    0.181464    0.245096
# min     -0.606312   -0.378928   -0.436006   -0.518826   -0.391794   -0.595545
# 25%     -0.297873   -0.139883   -0.151032   -0.192556   -0.179872   -0.234269
# 50%     -0.091043   -0.033554   -0.023823   -0.013966   -0.036692   -0.029015
# 75%      0.178698    0.072746    0.086778    0.087972    0.079632    0.135943
# max      0.675767    0.389959    0.389371    0.503813    0.537385    0.520400
#
#                V7          V8          V9         V10  ...         V43  \
# count  363.000000  363.000000  363.000000  363.000000  ...  363.000000
# mean    -0.031224   -0.039428   -0.038843   -0.035525  ...   -0.032524
# ...

# %%
updated_df = X_train
updated_df['ctnum']=updated_df['ctnum'].fillna(updated_df['ctnum'].mean())
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 363 entries, 397 to 102
# Data columns (total 54 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rowname  363 non-null    object
#  1   V1       363 non-null    float64
#  2   V2       363 non-null    float64
#  3   V3       363 non-null    float64
#  4   V4       363 non-null    float64
#  5   V5       363 non-null    float64
#  6   V6       363 non-null    float64
#  7   V7       363 non-null    float64
#  8   V8       363 non-null    float64
#  9   V9       363 non-null    float64
#  10  V10      363 non-null    float64
#  11  V11      363 non-null    float64
#  12  V12      363 non-null    float64
#  13  V13      363 non-null    float64
#  14  V14      363 non-null    float64
#  15  V15      363 non-null    float64
#  16  V16      363 non-null    float64
#  17  V17      363 non-null    float64
#  18  V18      363 non-null    float64
#  19  V19      363 non-null    float64
# ...

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 3000

# %%
X_train = updated_df
X_train['agenum']=X_train['agenum'].fillna(X_train['agenum'].mean())
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 363 entries, 397 to 102
# Data columns (total 54 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rowname  363 non-null    object
#  1   V1       363 non-null    float64
#  2   V2       363 non-null    float64
#  3   V3       363 non-null    float64
#  4   V4       363 non-null    float64
#  5   V5       363 non-null    float64
#  6   V6       363 non-null    float64
#  7   V7       363 non-null    float64
#  8   V8       363 non-null    float64
#  9   V9       363 non-null    float64
#  10  V10      363 non-null    float64
#  11  V11      363 non-null    float64
#  12  V12      363 non-null    float64
#  13  V13      363 non-null    float64
#  14  V14      363 non-null    float64
#  15  V15      363 non-null    float64
#  16  V16      363 non-null    float64
#  17  V17      363 non-null    float64
#  18  V18      363 non-null    float64
#  19  V19      363 non-null    float64
# ...

# %%
X_train
# Out:
#         rowname        V1        V2        V3        V4        V5        V6  \
# 397  GSM4602639 -0.330218  0.010943 -0.210595  0.042186  0.239706 -0.086893
# 57   GSM4602298  0.426675  0.201063 -0.024022 -0.013352  0.077604  0.044928
# 286  GSM4602527 -0.449942 -0.190835  0.044374  0.144829 -0.079280 -0.086654
# 132  GSM4602373 -0.385247 -0.206050 -0.239616 -0.120262 -0.137117 -0.310101
# 406  GSM4602648  0.008941 -0.073164 -0.227340 -0.243443 -0.297489 -0.101534
# ..          ...       ...       ...       ...       ...       ...       ...
# 106  GSM4602347 -0.178225  0.033551  0.130311  0.309763  0.053018  0.246189
# 270  GSM4602511 -0.084461 -0.050759 -0.028248  0.007801  0.076674 -0.079665
# 348  GSM4602589  0.001382  0.137369  0.023774 -0.089512  0.381360 -0.220417
# 435  GSM4602677 -0.065488 -0.064513 -0.098331  0.007988 -0.174017  0.171827
# 102  GSM4602343  0.517276  0.207840  0.254931  0.265622  0.187722  0.370110
#
# ...

# %%
 pd.get_dummies(X_train,columns = ['batch'], drop_first = True).shape
# Out:
# (2, 1)

# %%
X_train
# Out:
# (363, 73)
