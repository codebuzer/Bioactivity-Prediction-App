# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzer/Bioactivity-Prediction-App/blob/main/dataectraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('/content/drive/MyDrive/data_t20'):
    filenames.append(os.path.join('/content/drive/MyDrive/data_t20',file))

# %%
filenames[404:405]
# Out:
# ['/content/drive/MyDrive/data_t20/685727.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|██████████| 1432/1432 [07:49<00:00,  3.05it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Germany', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sierra Leone', 'del...                0.9
# 0   [{'1st innings': {'team': 'United Arab Emirate...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Botswana', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Ghana', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
#
# ...

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Germany', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sierra Leone', 'del...                0.9
# 0   [{'1st innings': {'team': 'United Arab Emirate...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Botswana', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Ghana', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
#
#    meta.created  meta.revision   info.city    info.dates info.gender  \
# ...

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Germany', 'deliveri...     Almeria
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...   Singapore
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Colombo
# 0   [{'1st innings': {'team': 'Sierra Leone', 'del...    Gaborone
# 0   [{'1st innings': {'team': 'United Arab Emirate...       Dubai
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...     Bangkok
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...    Brisbane
# 0   [{'1st innings': {'team': 'Botswana', 'deliver...    Windhoek
# 0   [{'1st innings': {'team': 'Ghana', 'deliveries...     Kampala
# 0   [{'1st innings': {'team': 'India', 'deliveries...  Wellington
#
#       info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0   [2020-03-08]        male             T20             Germany          20
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Germany', 'deliveri...     Almeria
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...   Singapore
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Colombo
# 0   [{'1st innings': {'team': 'United Arab Emirate...       Dubai
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Kitts
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...    Brisbane
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...   Abu Dhabi
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Germany', 'deliveri...     Almeria
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...   Singapore
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Colombo
# 0   [{'1st innings': {'team': 'United Arab Emirate...       Dubai
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Kitts
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...    Brisbane
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...   Abu Dhabi
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'R Panchal',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'non_striker': 'Abdul-Shakoor Rahimzei',
#    'batsman': 'VB Chikkannaiah'}},
#  {0.2: {'bowler': 'R Panchal',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Abdul-Shakoor Rahimzei',
#    'batsman': 'VB Chikkannaiah'}},
#  {0.3: {'bowler': 'R Panchal',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Abdul-Shakoor Rahimzei',
#    'batsman': 'VB Chikkannaiah'}},
#  {0.4: {'bowler': 'R Panchal',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Abdul-Shakoor Rahimzei',
#    'batsman': 'VB Chikkannaiah'}},
#  {0.5: {'bowler': 'R Panchal',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'Abdul-Shakoor Rahimzei',
#    'batsman': 'VB Chikkannaiah'}},
#  {0.6: {'non_striker': 'VB Chikkannaiah',
#    'bowler': 'R Panchal',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#      match_id                 teams batting_team  ball          batsman  \
# 0           2      [Spain, Germany]      Germany   0.1  VB Chikkannaiah
# 1           2      [Spain, Germany]      Germany   0.2  VB Chikkannaiah
# 2           2      [Spain, Germany]      Germany   0.3  VB Chikkannaiah
# 3           2      [Spain, Germany]      Germany   0.4  VB Chikkannaiah
# 4           2      [Spain, Germany]      Germany   0.5  VB Chikkannaiah
# ..        ...                   ...          ...   ...              ...
# 122       964  [New Zealand, India]        India  19.3         NA Saini
# 123       964  [New Zealand, India]        India  19.4        MK Pandey
# 124       964  [New Zealand, India]        India  19.5        MK Pandey
# 125       964  [New Zealand, India]        India  19.6        MK Pandey
# 126       964  [New Zealand, India]        India  19.7         NA Saini
#
#             bowler  runs player_dismissed        city  \
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                 teams batting_team  ball          batsman  \
# 0           2      [Spain, Germany]      Germany   0.1  VB Chikkannaiah
# 1           2      [Spain, Germany]      Germany   0.2  VB Chikkannaiah
# 2           2      [Spain, Germany]      Germany   0.3  VB Chikkannaiah
# 3           2      [Spain, Germany]      Germany   0.4  VB Chikkannaiah
# 4           2      [Spain, Germany]      Germany   0.5  VB Chikkannaiah
# ..        ...                   ...          ...   ...              ...
# 122       964  [New Zealand, India]        India  19.3         NA Saini
# 123       964  [New Zealand, India]        India  19.4        MK Pandey
# 124       964  [New Zealand, India]        India  19.5        MK Pandey
# 125       964  [New Zealand, India]        India  19.6        MK Pandey
# 126       964  [New Zealand, India]        India  19.7         NA Saini
#
#             bowler  runs player_dismissed        city  \
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Germany', 'Malaysia', 'Sri Lanka', 'United Arab Emirates',
#        'West Indies', 'England', 'India', 'Zimbabwe', 'Ireland', 'Kenya',
#        'Afghanistan', 'Nepal', 'Pakistan', 'Australia', 'Bangladesh',
#        'South Africa', 'New Zealand', 'Nigeria', 'Netherlands', 'Vanuatu',
#        'Thailand', 'United States of America', 'Namibia',
#        'Papua New Guinea', 'Oman', 'Norway', 'Singapore', 'Scotland',
#        'Bermuda', 'Denmark', 'Gibraltar', 'Hong Kong', 'Jersey',
#        'Cayman Islands', 'Qatar', 'Uganda', 'Philippines', 'Bulgaria',
#        'Portugal', 'Maldives', 'Bhutan', 'Iran', 'Canada', 'Italy',
#        'Guernsey', 'Spain', 'Belgium', 'Botswana', 'Ghana', 'Romania',
#        'Kuwait', 'Isle of Man'], dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball         batsman           bowler  runs  \
# 0           4    Sri Lanka   0.1  MD Gunathilaka  Shakib Al Hasan     0
# 1           4    Sri Lanka   0.2  MD Gunathilaka  Shakib Al Hasan     0
# 2           4    Sri Lanka   0.3  MD Gunathilaka  Shakib Al Hasan     0
# 3           4    Sri Lanka   0.4  MD Gunathilaka  Shakib Al Hasan     1
# 4           4    Sri Lanka   0.5      BKG Mendis  Shakib Al Hasan     1
# ..        ...          ...   ...             ...              ...   ...
# 122       964        India  19.3        NA Saini    SC Kuggeleijn     1
# 123       964        India  19.4       MK Pandey    SC Kuggeleijn     1
# 124       964        India  19.5       MK Pandey    SC Kuggeleijn     2
# 125       964        India  19.6       MK Pandey    SC Kuggeleijn     1
# 126       964        India  19.7        NA Saini    SC Kuggeleijn     1
#
#     player_dismissed        city                            venue bowling_team
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           4    Sri Lanka   Bangladesh   0.1     0                0
# 1           4    Sri Lanka   Bangladesh   0.2     0                0
# 2           4    Sri Lanka   Bangladesh   0.3     0                0
# 3           4    Sri Lanka   Bangladesh   0.4     1                0
# 4           4    Sri Lanka   Bangladesh   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 122       964        India  New Zealand  19.3     1                0
# 123       964        India  New Zealand  19.4     1                0
# 124       964        India  New Zealand  19.5     2                0
# 125       964        India  New Zealand  19.6     1                0
# 126       964        India  New Zealand  19.7     1                0
#
#            city                            venue
# 0       Colombo  R.Premadasa Stadium, Khettarama
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
