# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzer/Bioactivity-Prediction-App/blob/main/pysam_gene_wise_coverage_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pysam

# %%
#import pysam

# Open the BAM file
#bam_file = "/content/drive/MyDrive/gene wise coverage/IGIB113050041V.bam"
#bam = pysam.AlignmentFile(bam_file, "rb")

# %%
# Load the GTF file using pybedtools
#from pybedtools import BedTool
#genes = BedTool(gtf_file)

# %%
#import subprocess

#bam_file = "/content/drive/MyDrive/gene wise coverage/IGIB113050041V.bam"

# Create the index using samtools
#subprocess.run(["samtools", "index", bam_file])

# %%
#!apt-get install samtools

# %%
#result_df.to_csv('fetch_coverage.csv', index=False)

# %%
import subprocess
import pysam
from pybedtools import BedTool
import pandas as pd

def calculate_gene_coverage(bam_file, gtf_file):
    subprocess.run(["samtools", "index", bam_file])
    bam = pysam.AlignmentFile(bam_file, "rb")
    genes = BedTool(gtf_file)
    coverage_data = []
    for gene in genes:
        chrom = gene.chrom
        start = gene.start
        end = gene.end
        coverage = bam.count_coverage(chrom, start, end)
        gene_coverage = sum(coverage[0])
        gene_name = gene.name
        coverage_data.append((gene_name, gene_coverage))
    df = pd.DataFrame(coverage_data, columns=['Gene', 'Coverage'])
    bam.close()

    return df

# %%
bam_file = "/content/drive/MyDrive/gene wise coverage/IGIB113050041V.bam"
gtf_file = "/content/drive/MyDrive/gene wise coverage/Homo_sapiens.GRCh38.106.gtf"

result_df = calculate_gene_coverage(bam_file, gtf_file)

# %%
result_df.to_csv('count_coverage.csv')

# %%
result_df
# Out:
#                     Gene  Coverage
# 0                TNFRSF4        33
# 1                TNFRSF4        33
# 2                TNFRSF4         0
# 3                TNFRSF4         0
# 4                TNFRSF4         0
# ...                  ...       ...
# 3279400  ENST00000612315         0
# 3279401  ENST00000612315        17
# 3279402               U1       245
# 3279403               U1       245
# 3279404               U1       245
#
# [3279405 rows x 2 columns]

# %%
#coverage = bam.count_coverage('2', 800, 9000)

# %%
#coverage

# %%
grouped_df = result_df.groupby('Gene')['Coverage'].sum().reset_index()
# Out:
#                  Gene  Coverage
# 0             5S_rRNA        96
# 1           5_8S_rRNA      3966
# 2                 7SK    786453
# 3                A1BG      1210
# 4            A1BG-AS1      1068
# ...               ...       ...
# 91784            ZZZ3     41427
# 91785    hsa-mir-1253        69
# 91786     hsa-mir-423         0
# 91787  hsa-mir-8069-1         0
# 91788         snoZ196         0
#
# [91789 rows x 2 columns]

# %%
grouped_df[grouped_df['Gene'] == 'TNFRSF4']
# Out:
#           Gene  Coverage
# 88250  TNFRSF4       138

# %%
#grouped_df.to_csv('count_coverage_IGIB113050041V.csv')

# %%
grouped_df[grouped_df['Gene'] == 'TNFRSF4']
# Out:
#           Gene  Coverage
# 88250  TNFRSF4       138

# %%
grouped_df[grouped_df['Coverage'] == 0]
# Out:
#                  Gene  Coverage
# 34            AARS1P1         0
# 37           AARSD1P1         0
# 64           ABCB10P1         0
# 102           ABCF2P2         0
# 122           ABHD16B         0
# ...               ...       ...
# 91775            ZXDA         0
# 91779        ZYG11AP1         0
# 91786     hsa-mir-423         0
# 91787  hsa-mir-8069-1         0
# 91788         snoZ196         0
#
# [29778 rows x 2 columns]

# %%
import subprocess
import pysam
import pandas as pd

def calculate_gene_coverage(bam_file, gtf_file):
    subprocess.run(["samtools", "index", bam_file])
    bam = pysam.AlignmentFile(bam_file, "rb")
    gene_annotations = pd.read_csv(gtf_file, sep='\t', comment='#', header=None, dtype={0: str})
    gene_annotations = gene_annotations[gene_annotations[2] == "gene"]
    coverage_data = []
    for _, gene in gene_annotations.iterrows():
        chrom = gene[0]
        start = gene[3]
        end = gene[4]
        coverage = bam.count_coverage(chrom, start, end)
        gene_coverage = sum(sum(position_coverage) for position_coverage in coverage)
        gene_name = gene[8].split(";")[0].split(" ")[1].replace('"', '')
        coverage_data.append((gene_name, gene_coverage))
    df = pd.DataFrame(coverage_data, columns=['Gene', 'Coverage'])

    bam.close()

    return df

bam_file = "/content/drive/MyDrive/gene wise coverage/IGIB113050041V.bam"
gtf_file = "/content/drive/MyDrive/gene wise coverage/Homo_sapiens.GRCh38.106.gtf"

result_df = calculate_gene_coverage(bam_file, gtf_file)

# %%
#gene[8].split(";")[0].split(" ")[2].replace('"', '')
#gene[8].split(";")[0].split(" ")[1].replace('"', '')
# Out:
# 'ENSG00000275405'

# %%
result_df
# Out:
#                   Gene  Coverage
# 0      ENSG00000186827       301
# 1      ENSG00000186891        71
# 2      ENSG00000160072      9597
# 3      ENSG00000260179       582
# 4      ENSG00000234396      1700
# ...                ...       ...
# 61547  ENSG00000271254     17988
# 61548  ENSG00000275987         0
# 61549  ENSG00000268674       154
# 61550  ENSG00000277475       321
# 61551  ENSG00000275405       948
#
# [61552 rows x 2 columns]

# %%
result_df[result_df['Gene'] == 'ensembl']
#result_df
# Out:
#           Gene  Coverage
# 2004   ensembl       164
# 2009   ensembl         0
# 2011   ensembl       158
# 2047   ensembl         0
# 2051   ensembl         0
# ...        ...       ...
# 61545  ensembl         0
# 61546  ensembl         0
# 61547  ensembl     17988
# 61549  ensembl       154
# 61550  ensembl       321
#
# [672 rows x 2 columns]

# %%
gene_annotations = pd.read_csv(gtf_file, sep='\t', comment='#', header=None, dtype={0: str})

# %%
gene_annotations
# Out:
#                   0               1                2        3        4  5  6  \
# 0                 1  ensembl_havana             gene  1211340  1214153  .  -
# 1                 1  ensembl_havana       transcript  1211340  1214153  .  -
# 2                 1  ensembl_havana             exon  1213983  1214153  .  -
# 3                 1  ensembl_havana              CDS  1213983  1214127  .  -
# 4                 1  ensembl_havana      start_codon  1214125  1214127  .  -
# ...             ...             ...              ...      ...      ... .. ..
# 3279400  KI270713.1         ensembl   five_prime_utr    32373    32528  .  -
# 3279401  KI270713.1         ensembl  three_prime_utr    31698    31841  .  -
# 3279402  KI270713.1         ensembl             gene    21861    22024  .  -
# 3279403  KI270713.1         ensembl       transcript    21861    22024  .  -
# 3279404  KI270713.1         ensembl             exon    21861    22024  .  -
#
#          7                                                  8
# 0        .  gene_id "ENSG00000186827"; gene_version "11"; ...
# 1        .  gene_id "ENSG00000186827"; gene_version "11"; ...
# 2        .  gene_id "ENSG00000186827"; gene_version "11"; ...
# 3        0  gene_id "ENSG00000186827"; gene_version "11"; ...
# 4        0  gene_id "ENSG00000186827"; gene_version "11"; ...
# ...     ..                                                ...
# 3279400  .  gene_id "ENSG00000277475"; gene_version "1"; t...
# 3279401  .  gene_id "ENSG00000277475"; gene_version "1"; t...
# 3279402  .  gene_id "ENSG00000275405"; gene_version "1"; g...
# 3279403  .  gene_id "ENSG00000275405"; gene_version "1"; t...
# 3279404  .  gene_id "ENSG00000275405"; gene_version "1"; t...
#
# [3279405 rows x 9 columns]

# %%
gene_annotations = gene_annotations[gene_annotations[2] == "gene"]

# %%
gene_annotations.head()
# Out:
#      0               1     2        3        4  5  6  7  \
# 0    1  ensembl_havana  gene  1211340  1214153  .  -  .
# 31   1  ensembl_havana  gene  1203508  1206592  .  -  .
# 84   1  ensembl_havana  gene  1471765  1497848  .  +  .
# 191  1          havana  gene  1249777  1251334  .  -  .
# 194  1          havana  gene  2212523  2220738  .  +  .
#
#                                                      8
# 0    gene_id "ENSG00000186827"; gene_version "11"; ...
# 31   gene_id "ENSG00000186891"; gene_version "14"; ...
# 84   gene_id "ENSG00000160072"; gene_version "20"; ...
# 191  gene_id "ENSG00000260179"; gene_version "1"; g...
# 194  gene_id "ENSG00000234396"; gene_version "3"; g...

# %%
gene_annotations[8][194]
# Out:
# 'gene_id "ENSG00000234396"; gene_version "3"; gene_source "havana"; gene_biotype "lncRNA";'

# %%
for _, gene in gene_annotations.iterrows():
  chrom = gene[0]
  start = gene[3]
  end = gene[4]

# %%
gene[0]
# Out:
# 'KI270713.1'

# %%
coverage = bam.count_coverage(chrom, start, end)

# %%
import numpy as np
np.sum(coverage)
# Out:
# 948

# %%
gene_coverage = sum(sum(position_coverage) for position_coverage in coverage)

# %%
gene_coverage
# Out:
# 948

# %%
gene_name = gene[8].split(";")[0].split(" ")[1].replace('"', '')

# %%
gene[8].split(";")[2].split(" ")[2].replace('"', '')
# Out:
# 'U1'

# %%
gene_name
# Out:
# 'ENSG00000275405'

# %%
gene[8]
# Out:
# 'gene_id "ENSG00000275405"; gene_version "1"; gene_name "U1"; gene_source "ensembl"; gene_biotype "snRNA";'
